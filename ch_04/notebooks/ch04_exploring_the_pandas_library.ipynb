# %%
import pandas as pd

# %%
my_df = pd.read_csv('evolution_of_data_analysis.csv', header=0, sep="|")

# %%
my_df.shape
# Out:
# (42, 7)

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 7 columns):
# Year                                42 non-null int64
# Decade                              42 non-null object
# Milestone Title                     42 non-null object
# Milestone Event                     42 non-null object
# Why Important                       42 non-null object
# Reference                           39 non-null object
# People Process or Technology Tag    42 non-null object
# dtypes: int64(1), object(6)
# memory usage: 2.4+ KB

# %%
my_df.describe()
# Out:
#               Year
# count    42.000000
# mean   1993.833333
# std      18.876901
# min    1945.000000
# 25%    1987.500000
# 50%    1999.000000
# 75%    2006.750000
# max    2018.000000

# %%
my_df.head(2)
# Out:
#    Year Decade           Milestone Title  \
# 0  1945  1940s                     ENIAC
# 1  1945  1940s  John von Neumann / array
#
#                                      Milestone Event  \
# 0  First electronic general-purpose computer = ENIAC
# 1  John von Neumann creates a merge sort algorith...
#
#                                        Why Important  \
# 0   Faster decisions using a computer and mathmatics
# 1  Arrays allow mathmatics| grouping and sorting ...
#
#                                         Reference  \
# 0             https://en.wikipedia.org/wiki/ENIAC
# 1  https://en.wikipedia.org/wiki/John_von_Neumann
#
#   People Process or Technology Tag
# 0                       Technology
# 1                           People

# %%
my_df.tail(2)
# Out:
#     Year Decade            Milestone Title  \
# 40  2015  2010s                      Alexa
# 41  2018  2010s  The Data Literacy Project
#
#                        Milestone Event  \
# 40              Amazon Alexa Ecosystem
# 41  The Data Literacy Project launches
#
#                                         Why Important  \
# 40  Making voice to data mainstream and allowing A...
# 41  Building a data driven culture where anyone ca...
#
#                                             Reference  \
# 40  https://www.zdnet.com/article/technology-that-...
# 41  https://www.businesswire.com/news/home/2018101...
#
#    People Process or Technology Tag
# 40                       Technology
# 41                          Process

# %%
my_df.sort_index(1)
# Out:
#    Decade                                    Milestone Event  \
# 0   1940s  First electronic general-purpose computer = ENIAC
# 1   1940s  John von Neumann creates a merge sort algorith...
# 2   1950s                  The first computer hard disk used
# 3   1950s                                 The modem invented
# 4   1960s      Statistician John Tukey defined data analysis
# 5   1970s  Dr. E.F. Codd creates concept of "normalizing ...
# 6   1970s  FORTRAN Programing Language supports comma sep...
# 7   1980s                      Bloomberg Terminal Introduced
# 8   1980s  Edward Tufty writes the book "The Visual Displ...
# 9   1980s  SQL Language Standardized across all database ...
# 10  1980s                                    Microsoft Excel
# 11  1980s  The term “BI (Business Intelligence)” was prop...
# 12  1990s  On-Line Analytical Processing (OLAP) and Busin...
# 13  1990s  Guido van Rossum creates the Python programmin...
# ...

# %%
my_df.groupby(['Decade']).agg({'Year':'count'})
# Out:
#         Year
# Decade
# 1940s      2
# 1950s      2
# 1960s      1
# 1970s      2
# 1980s      5
# 1990s      9
# 2000s     14
# 2010s      7
