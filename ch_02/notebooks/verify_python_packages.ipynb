# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.18.0'

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.10.4'

# %%
import sklearn as sk

# %%
sk.__version__
# Out:
# '0.17.1'

# %%
import matplotlib as mp

# %%
mp.__version__
# Out:
# '1.5.1'

# %%
import scipy as sc

# %%
sc.__version__
# Out:
# '0.17.0'
